# %% [markdown]
# Import necessary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# TODO 1: Read the data from ```data.csv``` using ```pandas```

# %%
# Complete TODO 1
# Store the column labelleed X as a numpy array named X 
df = pd.read_csv("data.csv")
X = np.array(df['X'])
# Store the column labeled y as a numpy array named y
y = np.array(df['y']) 
# Ensure that you reshape them properly

# %% [markdown]
# TODO 2: Complete the ```normalize``` function. For a numpy array X, normalized output will be
# ```(X - mean(X))/standard_devaiation(X)```

# %%
def normalize(X):
    #Complete TODO 2
    X_norm = (X - np.mean(X))/np.std(X)
    return X_norm

X_norm = normalize(X)
y_norm = normalize(y)
# Initialize parameters
theta = np.random.randn(2, 1)  # We have 2 parameters (theta_0 and theta_1)

# %% [markdown]
# TODO 3: Complete the function ```complete_cost``` function below. Refer to Problem statement for the cost (error) function for linear regression.
#
# Here, ```X``` : np.array of x-coordinates of points
#
# ```y``` : np.array of y-coordinates of points
#
# ```theta``` : np.array of parameters

# %%
def compute_cost(X, y, theta):
    m = len(y) 
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term (x0 = 1)
    #Complete TODO 3  
    y_pred = np.matmul(X_b, theta).reshape([m,])
    diff = np.square(y_pred - y) 
    cost = (1/(2*m))*np.sum(diff)
    return cost

# %% [markdown]
# ##### TODO 4: Implement Gradient Descent for linear regression according to algorithm given in the Problem Statement. Your only task is to update theta properly by finding the gradient correctly.

# %%
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y) 
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term (x0 = 1)
    cost_history = []
    for _ in range(iterations):
        #Complete TODO 4
        grad = (1/m)*np.matmul(np.transpose(X_b),(np.matmul(X_b,theta).reshape([m,])-y).reshape([X.shape[0],1]))
        theta = theta - (learning_rate*grad)
        # Update theta properly
        cost = compute_cost(X, y, theta)
        cost_history.append(cost)

    return theta, cost_history

# %% [markdown]
# TODO 5: Find ```theta_optimal``` and ```cost_history``` by calling the ```gradient_descent``` function. Also, print them.

# %%
learning_rate = 0.1
iterations = 1000

#Complete TODO 5
cost_history = []
theta_optimal, cost_history = gradient_descent(X_norm,y_norm, theta,learning_rate,iterations)
print(theta_optimal)
print(cost_history)
# Out:
# [[9.99178920e-16]
#  [8.77082403e-01]]
# [0.9818233489402421, 0.8171959262122611, 0.6838477138025963, 0.575835661750768, 0.4883458995887869, 0.41747919223758234, 0.36007715928310646, 0.3135815125899812, 0.2759200387685497, 0.24541424497319012, 0.22070455199894887, 0.20068970068981343, 0.1844776711294138, 0.17134592718549008, 0.1607092145909118, 0.15209347738930346, 0.1451147302560007, 0.13946194507802542, 0.1348831890838655, 0.1311743967285959, 0.12817027492082758, 0.1257369362565352, 0.12376593193845843, 0.12216941844081618, 0.12087624250772598, 0.11982877000192296, 0.11898031727222247, 0.11829307056116509, 0.11773640072520859, 0.11728549815808384, 0.11692026707871281, 0.11662442990442225, 0.11638480179324688, 0.11619070302319488, 0.11603348301945272, 0.11590613481642155, 0.11580298277196636, 0.11571942961595762, 0.11565175155959055, 0.11559693233393324, 0.11555252876115081, 0.11551656